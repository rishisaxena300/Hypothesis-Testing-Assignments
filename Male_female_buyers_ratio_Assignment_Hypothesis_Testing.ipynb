# %% [markdown]
# # Chisquare Test

# %% [markdown]
# #Sales of products in four different regions is tabulated for males and females. Find if male-female buyer rations are similar #across regions.!

# %% [markdown]
# ![ChiSq1.JPG](attachment:ChiSq1.JPG)

# %%
from scipy.stats import chi2_contingency

# %%
# defining the table
data = [[50, 42, 131,70], [550, 351, 480, 350]]

# %%
data
# Out:
# [[50, 42, 131, 70], [550, 351, 480, 350]]

# %%
stat, p, dof, expected = chi2_contingency(data)

# %%
p
# Out:
# 1.7443883043012612e-10

# %%
stat
# Out:
# 48.40706302764444

# %%
dof
# Out:
# 3

# %%
expected
# Out:
# array([[ 86.85770751,  56.89179842,  88.45009881,  60.80039526],
#        [513.14229249, 336.10820158, 522.54990119, 359.19960474]])

# %%
# interpret p-value
alpha = 0.05
print("p value is " + str(p))
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (H0 holds true)')
# Out:
# p value is 1.7443883043012612e-10
# Dependent (reject H0)

# %%
# that means both are dependent group, there exist an association between group
